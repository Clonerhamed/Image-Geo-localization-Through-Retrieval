# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# move into your mounted GDrive filesystem
# %cd /content/drive/MyDrive/pjc
# Out:
# /content/drive/MyDrive/pjc

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu116
# Collecting torch==1.13.1+cu116 (from -r requirements.txt (line 3))
#   Downloading https://download.pytorch.org/whl/cu116/torch-1.13.1%2Bcu116-cp310-cp310-linux_x86_64.whl (1977.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 GB 1.1 MB/s eta 0:00:00
# Collecting torchvision==0.14.1+cu116 (from -r requirements.txt (line 4))
#   Downloading https://download.pytorch.org/whl/cu116/torchvision-0.14.1%2Bcu116-cp310-cp310-linux_x86_64.whl (24.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 68.0 MB/s eta 0:00:00
# Collecting faiss-cpu==1.7.3 (from -r requirements.txt (line 5))
#   Downloading faiss_cpu-1.7.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.0/17.0 MB 57.5 MB/s eta 0:00:00
# Collecting pytorch-lightning==1.9.4 (from -r requirements.txt (line 6))
#   Downloading pytorch_lightning-1.9.4-py3-none-any.whl (827 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 kB 63.9 MB/s eta 0:00:00
# Collecting pytorch-metric-learning==2.0.1 (from -r requirements.txt (line 7))
#   Downloading pytorch_metric_learning-2.0.1-py3-none-any.whl (109 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.3/109.3 kB 14.9 MB/s eta 0:00:00
# Collecting opencv-python==4.7.0.72 (from -r requirements.txt (line 8))
#   Downloading opencv_python-4.7.0.72-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (61.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 23.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-image==0.19.3 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 9)) (0.19.3)
# Requirement already satisfied: googledrivedownloader==0.4 in /usr/local/lib/python3.10/dist-packages (from -r requirements.txt (line 10)) (0.4)
# Collecting gdown==4.7.1 (from -r requirements.txt (line 11))
#   Downloading gdown-4.7.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==1.13.1+cu116->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (9.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (4.66.4)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (6.0.1)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (2023.6.0)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning==1.9.4->-r requirements.txt (line 6))
#   Downloading torchmetrics-1.4.0.post0-py3-none-any.whl (868 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 69.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (24.1)
# Collecting lightning-utilities>=0.6.0.post0 (from pytorch-lightning==1.9.4->-r requirements.txt (line 6))
#   Downloading lightning_utilities-0.11.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from pytorch-metric-learning==2.0.1->-r requirements.txt (line 7)) (1.2.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 9)) (1.11.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 9)) (3.3)
# Requirement already satisfied: imageio>=2.4.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 9)) (2.31.6)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 9)) (2024.5.22)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image==0.19.3->-r requirements.txt (line 9)) (1.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown==4.7.1->-r requirements.txt (line 11)) (3.15.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from gdown==4.7.1->-r requirements.txt (line 11)) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown==4.7.1->-r requirements.txt (line 11)) (4.12.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.6.0.post0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (67.7.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown==4.7.1->-r requirements.txt (line 11)) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.14.1+cu116->-r requirements.txt (line 4)) (1.7.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning==2.0.1->-r requirements.txt (line 7)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->pytorch-metric-learning==2.0.1->-r requirements.txt (line 7)) (3.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>2021.06.0->pytorch-lightning==1.9.4->-r requirements.txt (line 6)) (4.0.3)
# Installing collected packages: faiss-cpu, torch, opencv-python, lightning-utilities, torchvision, torchmetrics, pytorch-metric-learning, gdown, pytorch-lightning
#   Attempting uninstall: torch
#     Found existing installation: torch 2.3.0+cu121
#     Uninstalling torch-2.3.0+cu121:
#       Successfully uninstalled torch-2.3.0+cu121
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.8.0.76
#     Uninstalling opencv-python-4.8.0.76:
#       Successfully uninstalled opencv-python-4.8.0.76
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.18.0+cu121
#     Uninstalling torchvision-0.18.0+cu121:
#       Successfully uninstalled torchvision-0.18.0+cu121
#   Attempting uninstall: gdown
#     Found existing installation: gdown 5.1.0
#     Uninstalling gdown-5.1.0:
#       Successfully uninstalled gdown-5.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.3.0+cu121 requires torch==2.3.0, but you have torch 1.13.1+cu116 which is incompatible.
# torchtext 0.18.0 requires torch>=2.3.0, but you have torch 1.13.1+cu116 which is incompatible.
# Successfully installed faiss-cpu-1.7.3 gdown-4.7.1 lightning-utilities-0.11.2 opencv-python-4.7.0.72 pytorch-lightning-1.9.4 pytorch-metric-learning-2.0.1 torch-1.13.1+cu116 torchmetrics-1.4.0.post0 torchvision-0.14.1+cu116

# %%
# this is an example of a basic experiments. You can choose to validate on tokyo_xs or sf_xs

# !python main.py --train_path /content/drive/MyDrive/Data/gsv_xs --val_path /content/drive/MyDrive/Data/sf_xs/val --test_path /content/drive/MyDrive/Data/tokyo_xs/test --num_workers 2 --max_epochs 10
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 408MB/s]
# Using 16bit None Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2024-06-21 10:07:09.411366: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-21 10:07:09.411408: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-21 10:07:09.412716: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-06-21 10:07:09.419853: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-06-21 10:07:10.467813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-06-21 10:07:11   NumExpr defaulting to 8 threads.
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Validation: 0it [00:00, ?it/s]/usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Validation DataLoader 0: 100% 126/126 [2:08:44<00:00, 61.30s/it]2024-06-21 12:18:05   Epoch[00]): recalls: R@1: 20.8, R@5: 32.4, R@10: 38.9, R@20: 46.0
# Validation DataLoader 0: 100% 126/126 [2:08:46<00:00, 61.32s/it]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃      Validate metric      ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │          val/R@1          │    20.755661203553107     │
# │          val/R@5          │     32.40335293381709     │
# └───────────────────────────┴───────────────────────────┘
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name    | Type       | Params
# ---------------------------------------
# 0 | model   | Sequential | 683 K
# 1 | pooling | GeM        | 1
# 2 | fc      | Linear     | 66.0 K
# 3 | loss_fn | CircleLoss | 0
# ---------------------------------------
# 749 K     Trainable params
# 0         Non-trainable params
# 749 K     Total params
# 1.498     Total estimated model params size (MB)
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Epoch 0:  13% 20/156 [1:18:20<8:52:45, 235.04s/it, loss=47.9, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 0:  26% 40/156 [1:54:31<5:32:08, 171.80s/it, loss=47.9, v_num=ault]
# Epoch 0:  38% 60/156 [1:54:37<3:03:24, 114.63s/it, loss=47.9, v_num=ault]
# Epoch 0:  51% 80/156 [1:54:43<1:48:59, 86.04s/it, loss=47.9, v_num=ault]
# Epoch 0:  64% 100/156 [1:54:49<1:04:17, 68.89s/it, loss=47.9, v_num=ault]
# Epoch 0:  77% 120/156 [1:54:55<34:28, 57.46s/it, loss=47.9, v_num=ault]
# Epoch 0:  90% 140/156 [1:55:00<13:08, 49.29s/it, loss=47.9, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:34<00:01,  3.52it/s]
# Epoch 0: 100% 156/156 [1:55:04<00:00, 44.26s/it, loss=47.9, v_num=ault]2024-06-21 14:13:12   Epoch[00]): recalls: R@1: 30.5, R@5: 44.4, R@10: 51.7, R@20: 58.7
# Epoch 0: 100% 156/156 [1:55:06<00:00, 44.27s/it, loss=40.7, v_num=ault]
# Epoch 1:  13% 20/156 [1:04:26<7:18:14, 193.34s/it, loss=34.7, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 1:  26% 40/156 [1:34:09<4:33:02, 141.23s/it, loss=34.7, v_num=ault]
# Epoch 1:  38% 60/156 [1:34:14<2:30:47, 94.25s/it, loss=34.7, v_num=ault]
# Epoch 1:  51% 80/156 [1:34:20<1:29:37, 70.76s/it, loss=34.7, v_num=ault]
# Epoch 1:  64% 100/156 [1:34:26<52:53, 56.67s/it, loss=34.7, v_num=ault]
# Epoch 1:  77% 120/156 [1:34:32<28:21, 47.27s/it, loss=34.7, v_num=ault]
# Epoch 1:  90% 140/156 [1:34:38<10:48, 40.56s/it, loss=34.7, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:34<00:01,  3.50it/s]
# Epoch 1: 100% 156/156 [1:34:42<00:00, 36.43s/it, loss=34.7, v_num=ault]2024-06-21 15:47:56   Epoch[01]): recalls: R@1: 40.3, R@5: 54.6, R@10: 61.1, R@20: 67.4
# Epoch 1: 100% 156/156 [1:34:44<00:00, 36.44s/it, loss=33.8, v_num=ault]
# Epoch 2:  13% 20/156 [49:08<5:34:07, 147.41s/it, loss=31.9, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 2:  26% 40/156 [1:12:27<3:30:08, 108.69s/it, loss=31.9, v_num=ault]
# Epoch 2:  38% 60/156 [1:12:33<1:56:06, 72.56s/it, loss=31.9, v_num=ault]
# Epoch 2:  51% 80/156 [1:12:39<1:09:01, 54.49s/it, loss=31.9, v_num=ault]
# Epoch 2:  64% 100/156 [1:12:45<40:44, 43.65s/it, loss=31.9, v_num=ault]
# Epoch 2:  77% 120/156 [1:12:50<21:51, 36.42s/it, loss=31.9, v_num=ault]
# Epoch 2:  90% 140/156 [1:12:56<08:20, 31.26s/it, loss=31.9, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:34<00:01,  3.48it/s]
# Epoch 2: 100% 156/156 [1:13:01<00:00, 28.08s/it, loss=31.9, v_num=ault]2024-06-21 17:00:59   Epoch[02]): recalls: R@1: 47.0, R@5: 61.7, R@10: 67.8, R@20: 74.1
# Epoch 2: 100% 156/156 [1:13:02<00:00, 28.10s/it, loss=31.3, v_num=ault]
# Epoch 3:  13% 20/156 [39:11<4:26:32, 117.59s/it, loss=30.6, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 3:  26% 40/156 [58:50<2:50:39, 88.27s/it, loss=30.6, v_num=ault]
# Epoch 3:  38% 60/156 [58:56<1:34:18, 58.94s/it, loss=30.6, v_num=ault]
# Epoch 3:  51% 80/156 [59:01<56:04, 44.27s/it, loss=30.6, v_num=ault]
# Epoch 3:  64% 100/156 [59:07<33:06, 35.47s/it, loss=30.6, v_num=ault]
# Epoch 3:  77% 120/156 [59:13<17:46, 29.61s/it, loss=30.6, v_num=ault]
# Epoch 3:  90% 140/156 [59:18<06:46, 25.42s/it, loss=30.6, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:33<00:01,  3.59it/s]
# Epoch 3: 100% 156/156 [59:23<00:00, 22.84s/it, loss=30.6, v_num=ault]2024-06-21 18:00:24   Epoch[03]): recalls: R@1: 50.2, R@5: 65.1, R@10: 70.9, R@20: 76.5
# Epoch 3: 100% 156/156 [59:25<00:00, 22.85s/it, loss=30.1, v_num=ault]
# Epoch 4:  13% 20/156 [30:41<3:28:43, 92.09s/it, loss=29.4, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 4:  26% 40/156 [47:14<2:17:01, 70.87s/it, loss=29.4, v_num=ault]
# Epoch 4:  38% 60/156 [47:20<1:15:44, 47.34s/it, loss=29.4, v_num=ault]
# Epoch 4:  51% 80/156 [47:26<45:03, 35.58s/it, loss=29.4, v_num=ault]
# Epoch 4:  64% 100/156 [47:31<26:36, 28.52s/it, loss=29.4, v_num=ault]
# Epoch 4:  77% 120/156 [47:37<14:17, 23.81s/it, loss=29.4, v_num=ault]
# Epoch 4:  90% 140/156 [47:42<05:27, 20.45s/it, loss=29.4, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:33<00:01,  3.60it/s]
# Epoch 4: 100% 156/156 [47:47<00:00, 18.38s/it, loss=29.4, v_num=ault]2024-06-21 18:48:13   Epoch[04]): recalls: R@1: 54.4, R@5: 67.9, R@10: 73.3, R@20: 79.3
# Epoch 4: 100% 156/156 [47:49<00:00, 18.39s/it, loss=29.2, v_num=ault]
# Epoch 5:  13% 20/156 [26:32<3:00:31, 79.64s/it, loss=28.2, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 5:  26% 40/156 [39:58<1:55:55, 59.96s/it, loss=28.2, v_num=ault]
# Epoch 5:  38% 60/156 [40:04<1:04:06, 40.07s/it, loss=28.2, v_num=ault]
# Epoch 5:  51% 80/156 [40:09<38:09, 30.12s/it, loss=28.2, v_num=ault]
# Epoch 5:  64% 100/156 [40:15<22:32, 24.16s/it, loss=28.2, v_num=ault]
# Epoch 5:  77% 120/156 [40:21<12:06, 20.18s/it, loss=28.2, v_num=ault]
# Epoch 5:  90% 140/156 [40:27<04:37, 17.34s/it, loss=28.2, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:34<00:01,  3.51it/s]
# Epoch 5: 100% 156/156 [40:31<00:00, 15.59s/it, loss=28.2, v_num=ault]2024-06-21 19:28:47   Epoch[05]): recalls: R@1: 56.3, R@5: 70.3, R@10: 75.4, R@20: 80.7
# Epoch 5: 100% 156/156 [40:33<00:00, 15.60s/it, loss=28.3, v_num=ault]
# Epoch 6:  13% 20/156 [21:35<2:26:50, 64.78s/it, loss=27.5, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 6:  26% 40/156 [31:47<1:32:12, 47.69s/it, loss=27.5, v_num=ault]
# Epoch 6:  38% 60/156 [31:53<51:00, 31.89s/it, loss=27.5, v_num=ault]
# Epoch 6:  51% 80/156 [31:58<30:22, 23.99s/it, loss=27.5, v_num=ault]
# Epoch 6:  64% 100/156 [32:04<17:57, 19.24s/it, loss=27.5, v_num=ault]
# Epoch 6:  77% 120/156 [32:10<09:39, 16.08s/it, loss=27.5, v_num=ault]
# Epoch 6:  90% 140/156 [32:15<03:41, 13.83s/it, loss=27.5, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:33<00:01,  3.62it/s]
# Epoch 6: 100% 156/156 [32:19<00:00, 12.44s/it, loss=27.5, v_num=ault]2024-06-21 20:01:08   Epoch[06]): recalls: R@1: 56.3, R@5: 69.8, R@10: 74.9, R@20: 80.5
# Epoch 6: 100% 156/156 [32:21<00:00, 12.45s/it, loss=27.4, v_num=ault]
# Epoch 7:  13% 20/156 [18:54<2:08:37, 56.75s/it, loss=26.7, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 7:  26% 40/156 [28:10<1:21:43, 42.27s/it, loss=26.7, v_num=ault]
# Epoch 7:  38% 60/156 [28:16<45:14, 28.27s/it, loss=26.7, v_num=ault]
# Epoch 7:  51% 80/156 [28:21<26:56, 21.27s/it, loss=26.7, v_num=ault]
# Epoch 7:  64% 100/156 [28:27<15:56, 17.07s/it, loss=26.7, v_num=ault]
# Epoch 7:  77% 120/156 [28:32<08:33, 14.27s/it, loss=26.7, v_num=ault]
# Epoch 7:  90% 140/156 [28:38<03:16, 12.28s/it, loss=26.7, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:33<00:01,  3.62it/s]
# Epoch 7: 100% 156/156 [28:42<00:00, 11.04s/it, loss=26.7, v_num=ault]2024-06-21 20:29:53   Epoch[07]): recalls: R@1: 57.6, R@5: 70.5, R@10: 75.9, R@20: 81.1
# Epoch 7: 100% 156/156 [28:44<00:00, 11.05s/it, loss=26.5, v_num=ault]
# Epoch 8:  13% 20/156 [15:54<1:48:10, 47.72s/it, loss=26.4, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 8:  26% 40/156 [23:07<1:07:04, 34.70s/it, loss=26.4, v_num=ault]
# Epoch 8:  38% 60/156 [23:13<37:09, 23.23s/it, loss=26.4, v_num=ault]
# Epoch 8:  51% 80/156 [23:19<22:09, 17.50s/it, loss=26.4, v_num=ault]
# Epoch 8:  64% 100/156 [23:25<13:07, 14.05s/it, loss=26.4, v_num=ault]
# Epoch 8:  77% 120/156 [23:31<07:03, 11.76s/it, loss=26.4, v_num=ault]
# Epoch 8:  90% 140/156 [23:37<02:41, 10.12s/it, loss=26.4, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:34<00:01,  3.49it/s]
# Epoch 8: 100% 156/156 [23:41<00:00,  9.11s/it, loss=26.4, v_num=ault]2024-06-21 20:53:36   Epoch[08]): recalls: R@1: 58.2, R@5: 71.5, R@10: 76.5, R@20: 81.7
# Epoch 8: 100% 156/156 [23:43<00:00,  9.12s/it, loss=26.2, v_num=ault]
# Epoch 9:  13% 20/156 [13:11<1:29:39, 39.55s/it, loss=25.7, v_num=ault]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/126 [00:00<?, ?it/s]
# Epoch 9:  26% 40/156 [19:34<56:46, 29.36s/it, loss=25.7, v_num=ault]
# Epoch 9:  38% 60/156 [19:40<31:28, 19.67s/it, loss=25.7, v_num=ault]
# Epoch 9:  51% 80/156 [19:45<18:46, 14.82s/it, loss=25.7, v_num=ault]
# Epoch 9:  64% 100/156 [19:51<11:07, 11.91s/it, loss=25.7, v_num=ault]
# Epoch 9:  77% 120/156 [19:57<05:59,  9.98s/it, loss=25.7, v_num=ault]
# Epoch 9:  90% 140/156 [20:02<02:17,  8.59s/it, loss=25.7, v_num=ault]
# Validation DataLoader 0:  95% 120/126 [00:33<00:01,  3.62it/s]
# Epoch 9: 100% 156/156 [20:06<00:00,  7.74s/it, loss=25.7, v_num=ault]2024-06-21 21:13:44   Epoch[09]): recalls: R@1: 58.6, R@5: 71.5, R@10: 76.9, R@20: 81.9
# Epoch 9: 100% 156/156 [20:08<00:00,  7.75s/it, loss=25.9, v_num=ault]
# Epoch 9: 100% 156/156 [20:08<00:00,  7.75s/it, loss=25.9, v_num=ault]`Trainer.fit` stopped: `max_epochs=10` reached.
# Epoch 9: 100% 156/156 [20:08<00:00,  7.75s/it, loss=25.9, v_num=ault]
# Restoring states from the checkpoint path at logs/lightning_logs/default/checkpoints/_epoch(09)_R@1[58.5512]_R@5[71.4750].ckpt
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Loaded model weights from checkpoint at logs/lightning_logs/default/checkpoints/_epoch(09)_R@1[58.5512]_R@5[71.4750].ckpt
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/trainer/connectors/data_connector.py:224: PossibleUserWarning: The dataloader, test_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Testing DataLoader 0: 100% 103/103 [1:22:38<00:00, 48.15s/it]2024-06-21 22:38:10   Epoch[10]): recalls: R@1: 33.7, R@5: 50.8, R@10: 59.4, R@20: 66.3
# Testing DataLoader 0: 100% 103/103 [1:22:39<00:00, 48.15s/it]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃        Test metric        ┃       DataLoader 0        ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │         test/R@1          │     33.65079365079365     │
# │         test/R@5          │     50.79365079365079     │
# └───────────────────────────┴───────────────────────────┘

# %%
# this is an example of a basic experiments. You can choose to validate on tokyo_xs or sf_xs

# !python test.py --test_path /content/drive/MyDrive/Data/sf_xs/test --num_workers 2 --max_epochs 10
